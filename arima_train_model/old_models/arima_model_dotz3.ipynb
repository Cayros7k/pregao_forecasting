# %%
import matplotlib.pyplot as plt
import pandas as pd
import warnings

from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from math import sqrt
from pmdarima import auto_arima
from pandas.plotting import autocorrelation_plot

# %%
# Generate random data for the histogram
data = pd.read_csv('../dataset/dados_pregao_dotz3.csv', header=0, parse_dates=True, index_col=0)
df = data[['preco_ultimo_negocio']]
 
df.hist()
plt.show()

# %%
print(df.head())
df.plot()
plt.show
# Out:
#              preco_ultimo_negocio
# data_pregao
# 2021-05-31                  13.20
# 2021-06-01                  13.18
# 2021-06-02                  13.32
# 2021-06-04                  13.14
# 2021-06-07                  13.15
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
autocorrelation_plot(df)
plt.show()

# %%
warnings.filterwarnings('ignore')

# %%
stepwise_fit = auto_arima(df['preco_ultimo_negocio'], trace=True, suppress_warnings=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=615.004, Time=1.36 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=615.288, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=610.180, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=610.139, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=613.870, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=612.132, Time=0.30 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=612.128, Time=0.17 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=614.136, Time=0.21 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=608.632, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=610.622, Time=0.12 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=610.617, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=608.664, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=612.631, Time=0.17 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 2.797 seconds

# %%
X = df.values
size = int(len(X) * 0.8)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = []

# Loop de previsão
for t in range(len(test)):
    model = ARIMA(history, order=(0,1,1))  # Substituir os parâmetros com o melhor modelo de auto_arima
    model_fit = model.fit()

    output = model_fit.forecast()
    yhat = output[0]

    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))

# Cálculo do RMSE
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)

# Plotar os resultados
plt.figure(figsize=(16, 4))
plt.plot(test, label='Observed')
plt.plot(predictions, color='red', label='Predicted')
plt.legend()
plt.show()
# Out:
# predicted=8.026884, expected=7.490000
# predicted=7.446795, expected=7.190000
# predicted=7.168896, expected=7.280000
# predicted=7.289132, expected=7.150000
# predicted=7.138590, expected=7.380000
# predicted=7.399693, expected=7.190000
# predicted=7.173035, expected=7.150000
# predicted=7.148135, expected=7.230000
# predicted=7.236633, expected=7.280000
# predicted=7.283515, expected=7.360000
# predicted=7.366203, expected=7.240000
# predicted=7.229779, expected=7.100000
# predicted=7.089465, expected=6.970000
# predicted=6.960282, expected=6.750000
# predicted=6.732836, expected=6.860000
# predicted=6.870338, expected=6.620000
# predicted=6.599750, expected=6.940000
# predicted=6.967150, expected=6.720000
# predicted=6.700551, expected=6.630000
# predicted=6.624429, expected=6.680000
# predicted=6.684391, expected=6.520000
# predicted=6.507031, expected=6.320000
# predicted=6.305180, expected=6.320000
# predicted=6.321174, expected=6.440000
# predicted=6.449420, expected=6.250000
# predicted=6.234248, expected=6.170000
# predicted=6.164917, expected=6.020000
# predicted=6.008517, expected=6.020000
# predicted=6.020910, expected=6.010000
# predicted=6.009136, expected=6.060000
# predicted=6.064029, expected=6.000000
# predicted=5.994931, expected=5.980000
# predicted=5.978818, expected=5.950000
# predicted=5.947718, expected=5.900000
# predicted=5.896221, expected=5.510000
# predicted=5.479331, expected=5.450000
# predicted=5.447671, expected=5.380000
# predicted=5.374617, expected=5.170000
# predicted=5.153692, expected=4.820000
# predicted=4.793175, expected=4.760000
# predicted=4.757331, expected=5.180000
# predicted=5.214053, expected=5.520000
# predicted=5.545059, expected=5.880000
# predicted=5.907804, expected=5.600000
# predicted=5.574783, expected=5.220000
# predicted=5.190453, expected=5.370000
# predicted=5.384832, expected=5.260000
# predicted=5.249718, expected=5.540000
# predicted=5.563778, expected=5.450000
# predicted=5.440733, expected=5.470000
# predicted=5.472384, expected=5.520000
# predicted=5.523881, expected=5.430000
# predicted=5.422353, expected=6.340000
# predicted=6.413792, expected=7.370000
# predicted=7.455748, expected=7.600000
# predicted=7.613152, expected=7.510000
# predicted=7.500521, expected=8.750000
# predicted=8.862872, expected=8.600000
# predicted=8.577618, expected=8.800000
# predicted=8.819045, expected=8.880000
# predicted=8.885235, expected=8.790000
# predicted=8.781802, expected=8.830000
# predicted=8.834146, expected=8.100000
# predicted=8.037317, expected=8.200000
# predicted=8.213594, expected=8.660000
# predicted=8.697992, expected=8.670000
# predicted=8.667625, expected=8.280000
# predicted=8.246931, expected=8.750000
# predicted=8.791782, expected=8.770000
# predicted=8.768196, expected=8.550000
# predicted=8.531842, expected=8.450000
# predicted=8.443177, expected=8.290000
# predicted=8.277207, expected=8.370000
# predicted=8.377734, expected=8.440000
# predicted=8.445195, expected=8.360000
# predicted=8.352896, expected=8.300000
# predicted=8.295586, expected=8.170000
# predicted=8.159513, expected=8.190000
# predicted=8.192544, expected=7.880000
# predicted=7.853957, expected=8.000000
# predicted=8.012082, expected=7.920000
# predicted=7.912411, expected=8.000000
# predicted=8.007230, expected=8.120000
# predicted=8.129303, expected=8.050000
# predicted=8.043467, expected=8.000000
# predicted=7.996417, expected=7.750000
# predicted=7.729660, expected=7.580000
# predicted=7.567573, expected=6.850000
# predicted=6.789658, expected=6.920000
# predicted=6.930771, expected=6.670000
# predicted=6.648452, expected=7.090000
# predicted=7.125854, expected=6.920000
# predicted=6.903478, expected=6.840000
# predicted=6.834896, expected=6.840000
# predicted=6.840410, expected=6.990000
# predicted=7.002030, expected=6.800000
# predicted=6.783822, expected=6.320000
# predicted=6.282371, expected=6.600000
# predicted=6.625253, expected=6.400000
# predicted=6.382278, expected=6.340000
# predicted=6.336667, expected=6.400000
# predicted=6.405001, expected=6.550000
# predicted=6.561462, expected=6.460000
# predicted=6.451997, expected=6.390000
# predicted=6.385105, expected=6.490000
# predicted=6.498276, expected=6.630000
# predicted=6.640412, expected=6.540000
# predicted=6.532077, expected=6.680000
# predicted=6.691647, expected=6.580000
# predicted=6.571230, expected=6.520000
# predicted=6.515972, expected=6.410000
# predicted=6.401662, expected=6.650000
# predicted=6.669469, expected=6.460000
# predicted=6.443707, expected=6.580000
# predicted=6.590547, expected=6.450000
# predicted=6.439152, expected=6.470000
# predicted=6.472380, expected=6.670000
# predicted=6.685265, expected=6.540000
# predicted=6.528827, expected=6.660000
# predicted=6.670061, expected=6.670000
# predicted=6.669995, expected=6.570000
# predicted=6.562327, expected=6.580000
# predicted=6.581356, expected=6.610000
# predicted=6.612198, expected=6.410000
# predicted=6.394499, expected=6.100000
# predicted=6.077244, expected=6.300000
# predicted=6.317072, expected=6.500000
# predicted=6.514104, expected=6.000000
# predicted=5.960847, expected=5.870000
# predicted=5.863054, expected=5.510000
# predicted=5.482827, expected=6.850000
# predicted=6.948027, expected=7.610000
# predicted=7.662744, expected=8.390000
# predicted=8.451952, expected=8.330000
# predicted=8.319731, expected=8.800000
# predicted=8.840200, expected=8.520000
# predicted=8.493765, expected=8.010000
# predicted=7.969467, expected=7.590000
# predicted=7.557577, expected=8.180000
# predicted=8.231904, expected=8.700000
# predicted=8.740341, expected=9.000000
# predicted=9.022712, expected=8.810000
# predicted=8.791474, expected=8.500000
# predicted=8.474418, expected=7.900000
# predicted=7.848704, expected=7.650000
# predicted=7.632081, expected=7.640000
# predicted=7.640716, expected=8.010000
# predicted=8.043426, expected=7.550000
# predicted=7.506282, expected=6.840000
# predicted=6.778741, expected=6.610000
# predicted=6.594329, expected=6.380000
# predicted=6.359973, expected=6.300000
# predicted=6.294390, expected=6.230000
# predicted=6.223973, expected=6.580000
# predicted=6.613247, expected=5.870000
# predicted=5.802637, expected=5.610000
# predicted=5.592342, expected=5.400000
# predicted=5.382224, expected=5.260000
# predicted=5.248680, expected=5.620000
# predicted=5.654257, expected=5.450000
# predicted=5.431335, expected=5.150000
# predicted=5.124085, expected=5.030000
# predicted=5.021312, expected=4.960000
# predicted=4.954332, expected=4.800000
# predicted=4.785720, expected=4.810000
# predicted=4.812245, expected=4.890000
# predicted=4.897194, expected=5.500000
# predicted=5.556031, expected=5.500000
# Test RMSE: 0.313

# %%
X = df.values
history = [x for x in X]
model = ARIMA(history, order=(0,1,1))
model_fit = model.fit()
forecast = model_fit.forecast(steps=30)

# Gerar datas futuras
last_date = df.index[-1]
future_dates = pd.date_range(last_date, periods=30, freq='B')

# Adicionar previsões ao DataFrame
forecast_df = pd.DataFrame(forecast, index=future_dates, columns=['Forecast'])
df_with_forecast = pd.concat([df, forecast_df])

# Filtrar os dados apenas para o ano de 2024
df_2024 = df_with_forecast.loc['2024']

# Plotar os dados de 2024
plt.plot(df_2024, label='Original and Forecasted')
plt.legend()
plt.title('Previsões para o ano de 2024')
plt.show()
