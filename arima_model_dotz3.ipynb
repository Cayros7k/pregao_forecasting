# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot

data = pd.read_csv('./dataset/dados_pregao_dotz3.csv', header=0, parse_dates=True, index_col=0)
df = data[['preco_ultimo_negocio']]
print(df.head())
df.plot()
pyplot.show
# Out:
#              preco_ultimo_negocio
# data_pregao
# 2022-04-13                   3.54
# 2022-05-02                   3.06
# 2022-03-29                   2.95
# 2022-03-14                   1.94
# 2022-04-14                   3.41
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from pandas import read_csv
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot

autocorrelation_plot(df)
pyplot.show()

# %%
from pmdarima import auto_arima
import warnings

warnings.filterwarnings('ignore')

# %%
stepwise_fit = auto_arima(df['preco_ultimo_negocio'], trace=True, suppress_warnings=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1186.791, Time=0.73 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1203.062, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1199.367, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1198.923, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1201.073, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1187.910, Time=0.44 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1200.923, Time=0.29 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=1180.992, Time=0.42 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=1179.805, Time=0.36 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=1192.152, Time=0.15 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=1180.628, Time=0.44 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1200.597, Time=0.10 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=1182.057, Time=0.21 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=1182.551, Time=0.69 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=1177.812, Time=0.17 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=1198.934, Time=0.19 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=1190.160, Time=0.06 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=1178.635, Time=0.24 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=1178.999, Time=0.23 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=1198.608, Time=0.04 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=1184.800, Time=0.36 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=1180.064, Time=0.09 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=1180.558, Time=0.32 sec
#
# Best model:  ARIMA(3,1,1)(0,0,0)[0]
# Total fit time: 5.764 seconds

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt

X = df.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()

for t in range(len(test)):
    model = ARIMA(history, order=(3,1,1))
    model_fit = model.fit()

    output = model_fit.forecast()
    yhat = output[0]

    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))

rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)

pyplot.plot(test, label='Observed')
pyplot.plot(predictions, color='red', label='Predicted')
pyplot.legend()
pyplot.show()
# Out:
# predicted=8.145544, expected=8.200000
# predicted=8.309652, expected=8.660000
# predicted=8.579282, expected=8.670000
# predicted=8.618969, expected=8.280000
# predicted=8.309209, expected=8.750000
# predicted=8.747992, expected=8.770000
# predicted=8.716020, expected=8.550000
# predicted=8.553934, expected=8.450000
# predicted=8.510774, expected=8.290000
# predicted=8.314290, expected=8.370000
# predicted=8.390113, expected=8.440000
# predicted=8.416792, expected=8.360000
# predicted=8.363691, expected=8.300000
# predicted=8.313479, expected=8.170000
# predicted=8.202712, expected=8.190000
# predicted=8.197273, expected=7.880000
# predicted=7.932412, expected=8.000000
# predicted=8.005579, expected=7.920000
# predicted=7.945329, expected=8.000000
# predicted=7.965594, expected=8.120000
# predicted=8.128285, expected=8.050000
# predicted=8.010829, expected=8.000000
# predicted=8.042083, expected=7.750000
# predicted=7.768900, expected=7.580000
# predicted=7.654268, expected=6.850000
# predicted=6.961583, expected=6.920000
# predicted=7.004618, expected=6.670000
# predicted=6.720184, expected=7.090000
# predicted=7.031951, expected=6.920000
# predicted=6.937239, expected=6.840000
# predicted=6.812210, expected=6.840000
# predicted=6.910411, expected=6.990000
# predicted=6.914834, expected=6.800000
# predicted=6.861917, expected=6.320000
# predicted=6.351964, expected=6.600000
# predicted=6.672220, expected=6.400000
# predicted=6.367013, expected=6.340000
# predicted=6.385065, expected=6.400000
# predicted=6.393279, expected=6.550000
# predicted=6.529802, expected=6.460000
# predicted=6.447206, expected=6.390000
# predicted=6.410838, expected=6.490000
# predicted=6.486318, expected=6.630000
# predicted=6.600362, expected=6.540000
# predicted=6.532381, expected=6.680000
# predicted=6.667644, expected=6.580000
# predicted=6.586067, expected=6.520000
# predicted=6.525611, expected=6.410000
# predicted=6.449570, expected=6.650000
# predicted=6.613809, expected=6.460000
# predicted=6.480570, expected=6.580000
# predicted=6.552693, expected=6.450000
# predicted=6.494190, expected=6.470000
# predicted=6.438632, expected=6.670000
# predicted=6.685407, expected=6.540000
# predicted=6.493712, expected=6.660000
# predicted=6.687169, expected=6.670000
# predicted=6.633911, expected=6.570000
# predicted=6.597907, expected=6.580000
# predicted=6.574683, expected=6.610000
# predicted=6.623239, expected=6.410000
# predicted=6.417557, expected=6.100000
# predicted=6.180236, expected=6.300000
# predicted=6.299713, expected=6.500000
# predicted=6.470400, expected=6.000000
# predicted=6.021716, expected=5.870000
# predicted=5.958277, expected=5.510000
# predicted=5.584749, expected=6.850000
# predicted=6.688625, expected=7.610000
# predicted=7.384678, expected=8.390000
# predicted=8.125778, expected=8.330000
# predicted=8.310218, expected=8.800000
# predicted=8.661469, expected=8.520000
# predicted=8.596024, expected=8.010000
# predicted=7.999502, expected=8.010000
# predicted=8.165822, expected=8.010000
# predicted=7.935025, expected=8.010000
# predicted=8.080256, expected=6.300000
# predicted=6.452875, expected=6.300000
# predicted=6.514394, expected=6.300000
# predicted=6.327765, expected=13.140000
# predicted=11.995526, expected=13.150000
# predicted=12.753420, expected=13.100000
# predicted=12.049390, expected=12.820000
# predicted=13.500534, expected=12.830000
# predicted=12.371915, expected=12.750000
# predicted=13.161752, expected=13.200000
# predicted=12.812503, expected=13.180000
# predicted=13.426061, expected=12.750000
# predicted=12.611355, expected=13.320000
# predicted=13.387968, expected=12.910000
# predicted=12.915642, expected=13.040000
# predicted=12.980882, expected=13.120000
# predicted=13.197063, expected=13.150000
# predicted=13.067332, expected=13.200000
# predicted=13.232338, expected=13.600000
# predicted=13.527238, expected=13.500000
# predicted=13.501763, expected=13.260000
# predicted=13.233217, expected=13.800000
# predicted=13.805855, expected=13.600000
# predicted=13.589090, expected=13.770000
# predicted=13.699390, expected=13.920000
# predicted=13.960043, expected=14.160000
# predicted=14.064480, expected=14.000000
# predicted=14.026358, expected=13.950000
# predicted=13.920288, expected=13.950000
# predicted=14.000087, expected=14.000000
# predicted=13.970113, expected=13.810000
# predicted=13.843149, expected=16.000000
# predicted=15.761529, expected=17.150000
# predicted=16.965503, expected=16.690000
# predicted=16.383446, expected=16.500000
# predicted=16.594543, expected=16.400000
# predicted=16.440626, expected=16.690000
# predicted=16.676685, expected=17.000000
# predicted=16.962160, expected=16.960000
# predicted=16.907675, expected=16.780000
# predicted=16.787266, expected=16.500000
# predicted=16.547581, expected=16.000000
# predicted=16.073582, expected=15.550000
# predicted=15.641092, expected=14.450000
# predicted=14.608293, expected=12.930000
# predicted=13.115455, expected=12.480000
# predicted=12.680741, expected=12.590000
# predicted=12.696402, expected=12.690000
# predicted=12.663026, expected=12.170000
# predicted=12.199907, expected=11.870000
# predicted=11.901385, expected=11.100000
# predicted=11.227181, expected=10.110000
# predicted=10.186857, expected=10.150000
# predicted=10.275225, expected=9.800000
# predicted=9.862420, expected=10.150000
# predicted=10.105642, expected=10.300000
# predicted=10.340524, expected=9.990000
# predicted=9.923850, expected=9.800000
# predicted=9.862378, expected=9.800000
# predicted=9.811838, expected=9.780000
# predicted=9.797884, expected=9.490000
# predicted=9.496833, expected=9.220000
# predicted=9.256664, expected=9.280000
# predicted=9.309507, expected=9.310000
# predicted=9.318311, expected=9.010000
# predicted=9.012221, expected=9.050000
# predicted=9.065236, expected=9.130000
# predicted=9.150682, expected=9.200000
# predicted=9.169851, expected=9.290000
# predicted=9.289724, expected=9.100000
# predicted=9.095618, expected=8.950000
# predicted=8.965068, expected=9.170000
# predicted=9.182603, expected=8.820000
# predicted=8.835204, expected=8.570000
# predicted=8.573114, expected=8.600000
# predicted=8.661187, expected=8.660000
# predicted=8.643763, expected=8.630000
# predicted=8.634627, expected=8.770000
# predicted=8.752729, expected=8.500000
# predicted=8.521598, expected=8.970000
# predicted=8.928645, expected=8.910000
# predicted=8.941242, expected=8.600000
# predicted=8.540801, expected=8.430000
# predicted=8.514559, expected=8.490000
# predicted=8.480721, expected=8.400000
# predicted=8.429615, expected=8.400000
# predicted=8.378395, expected=8.250000
# predicted=8.286211, expected=7.660000
# predicted=7.682364, expected=7.510000
# predicted=7.569008, expected=7.490000
# predicted=7.538178, expected=6.910000
# predicted=6.932390, expected=6.660000
# predicted=6.706195, expected=6.130000
# predicted=6.220729, expected=6.290000
# predicted=6.286986, expected=6.880000
# predicted=6.902922, expected=6.320000
# predicted=6.272318, expected=6.190000
# predicted=6.200581, expected=6.150000
# predicted=6.226384, expected=6.260000
# predicted=6.218526, expected=6.190000
# predicted=6.220326, expected=5.990000
# predicted=5.971754, expected=5.730000
# predicted=5.782939, expected=5.200000
# predicted=5.238806, expected=4.620000
# predicted=4.698139, expected=4.340000
# predicted=4.408324, expected=4.190000
# predicted=4.241348, expected=4.030000
# predicted=4.047015, expected=3.990000
# predicted=4.009737, expected=4.000000
# predicted=4.007717, expected=4.150000
# predicted=4.140392, expected=4.290000
# predicted=4.277376, expected=4.150000
# predicted=4.138408, expected=4.710000
# predicted=4.680118, expected=4.950000
# predicted=4.935737, expected=5.260000
# predicted=5.168198, expected=5.380000
# predicted=5.389224, expected=5.610000
# predicted=5.545272, expected=5.010000
# predicted=5.059093, expected=4.700000
# predicted=4.694699, expected=4.400000
# predicted=4.513982, expected=4.010000
# predicted=4.005347, expected=4.200000
# predicted=4.255003, expected=4.100000
# predicted=4.099729, expected=3.940000
# predicted=3.932891, expected=3.800000
# predicted=3.835251, expected=3.670000
# predicted=3.679694, expected=3.540000
# predicted=3.564992, expected=3.500000
# predicted=3.508002, expected=3.430000
# predicted=3.445925, expected=3.220000
# predicted=3.228672, expected=3.240000
# predicted=3.254791, expected=3.200000
# predicted=3.214963, expected=3.150000
# predicted=3.141985, expected=3.150000
# predicted=3.163854, expected=3.290000
# predicted=3.278631, expected=3.330000
# predicted=3.326983, expected=3.250000
# predicted=3.237068, expected=3.360000
# predicted=3.364199, expected=3.130000
# predicted=3.141175, expected=3.060000
# predicted=3.057611, expected=3.000000
# predicted=3.036749, expected=3.100000
# predicted=3.080387, expected=3.000000
# predicted=3.019977, expected=3.020000
# predicted=2.999161, expected=3.030000
# predicted=3.055160, expected=3.010000
# predicted=2.989759, expected=3.020000
# predicted=3.034285, expected=2.870000
# predicted=2.869179, expected=2.600000
# predicted=2.623269, expected=2.680000
# predicted=2.694475, expected=3.070000
# predicted=3.066151, expected=2.700000
# predicted=2.686840, expected=2.790000
# predicted=2.772861, expected=3.000000
# predicted=3.039182, expected=2.990000
# predicted=2.937282, expected=2.550000
# predicted=2.587088, expected=2.610000
# predicted=2.610895, expected=2.890000
# predicted=2.923371, expected=2.850000
# predicted=2.801624, expected=2.470000
# predicted=2.494118, expected=2.540000
# predicted=2.549793, expected=3.000000
# predicted=3.009885, expected=2.850000
# predicted=2.810278, expected=2.400000
# predicted=2.406927, expected=2.810000
# predicted=2.833010, expected=2.450000
# predicted=2.478487, expected=2.850000
# predicted=2.782971, expected=2.450000
# predicted=2.536705, expected=2.830000
# predicted=2.725001, expected=2.430000
# predicted=2.551047, expected=2.850000
# predicted=2.719753, expected=2.800000
# predicted=2.915791, expected=2.770000
# predicted=2.640918, expected=2.140000
# predicted=2.278912, expected=2.750000
# predicted=2.660583, expected=2.930000
# predicted=3.016994, expected=2.850000
# predicted=2.703156, expected=2.270000
# predicted=2.394925, expected=2.810000
# predicted=2.738204, expected=3.070000
# predicted=3.138143, expected=2.800000
# predicted=2.678913, expected=2.240000
# predicted=2.349354, expected=2.860000
# predicted=2.818948, expected=3.140000
# predicted=3.175239, expected=2.930000
# predicted=2.813981, expected=2.100000
# predicted=2.214246, expected=2.990000
# predicted=2.945410, expected=3.180000
# predicted=3.235017, expected=3.000000
# predicted=2.835227, expected=2.180000
# predicted=2.342046, expected=2.850000
# predicted=2.783919, expected=3.280000
# predicted=3.354682, expected=3.060000
# predicted=2.886718, expected=2.200000
# predicted=2.340538, expected=2.770000
# predicted=2.739702, expected=3.190000
# predicted=3.254386, expected=2.050000
# predicted=1.953991, expected=3.150000
# predicted=3.186654, expected=3.180000
# predicted=3.202498, expected=3.120000
# predicted=2.949612, expected=2.040000
# Test RMSE: 0.578
